# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
sleep = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')

# %%
sleep.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# ...

# %%
sleep.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
sleep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
sleep.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
sleep['Physical Activity Level'].max()
# Out:
# 90

# %%
sleep['Physical Activity Level'].min()
# Out:
# 30

# %%
sleep['Physical Activity Level'].value_counts()
# Out:
# 60    70
# 30    68
# 45    68
# 75    67
# 90    67
# 40     6
# 55     6
# 35     4
# 50     4
# 70     3
# 42     2
# 32     2
# 80     2
# 65     2
# 85     2
# 47     1
# Name: Physical Activity Level, dtype: int64

# %%
sns.pairplot(data = sleep,hue = 'Sleep Disorder')

# %%
plt.figure(figsize = (12,8))
sns.countplot(data = sleep, x = "Physical Activity Level", hue = 'Gender')
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='count'>

# %%
plt.figure(figsize = (10,6))
sns.countplot(data = sleep , x = 'Sleep Duration')
# Out:
# <Axes: xlabel='Sleep Duration', ylabel='count'>

# %%
sleep['Sleep Duration'].value_counts()
# Out:
# 7.2    36
# 6.0    31
# 7.8    28
# 6.5    26
# 6.1    25
# 7.7    24
# 6.6    20
# 7.1    19
# 8.1    15
# 7.3    14
# 8.4    14
# 6.3    13
# 8.5    13
# 8.0    13
# 6.2    12
# 8.2    11
# 7.6    10
# 6.4     9
# 7.9     7
# 7.4     5
# 6.7     5
# 7.5     5
# 6.8     5
# 8.3     5
# 5.9     4
# 6.9     3
# 5.8     2
# Name: Sleep Duration, dtype: int64

# %%
sleep['Quality of Sleep'].value_counts()
# Out:
# 8    109
# 6    105
# 7     77
# 9     71
# 5      7
# 4      5
# Name: Quality of Sleep, dtype: int64

# %%
sns.countplot(data = sleep, x = 'Quality of Sleep')
# Out:
# <Axes: xlabel='Quality of Sleep', ylabel='count'>

# %%
sns.boxplot(data = sleep , x = 'Quality of Sleep', y = 'Sleep Duration')
# Out:
# <Axes: xlabel='Quality of Sleep', ylabel='Sleep Duration'>

# %%
sns.barplot(data = sleep, x = 'Physical Activity Level', y = 'Sleep Duration',hue = 'Gender')
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='Sleep Duration'>

# %%
sns.barplot(data = sleep, x = 'Physical Activity Level', y = 'Quality of Sleep',hue = 'Gender')
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='Quality of Sleep'>

# %%
sns.barplot(data = sleep, x = 'Physical Activity Level', y = 'Stress Level',hue = 'Gender')
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='Stress Level'>

# %%
sns.barplot(data = sleep, x = 'Stress Level',y = "Quality of Sleep")
# Out:
# <Axes: xlabel='Stress Level', ylabel='Quality of Sleep'>

# %%
sns.barplot(data = sleep,x = 'Quality of Sleep', y = 'Heart Rate')
# Out:
# <Axes: xlabel='Quality of Sleep', ylabel='Heart Rate'>

# %%
plt.figure(figsize = (14,8))
sns.barplot(data = sleep , x = 'Blood Pressure', y = "Quality of Sleep")
plt.tight_layout()

# %%
sleep['Blood Pressure'].max()
# Out:
# '142/92'

# %%
sleep['Blood Pressure'].min()
# Out:
# '115/75'

# %%
plt.figure(figsize = (14,8))
sns.barplot(data = sleep, x = 'Blood Pressure', y = 'Sleep Duration')
plt.tight_layout()

# %%
sleep[sleep['Physical Activity Level']>60]['BMI Category'].value_counts()
# Out:
# Overweight       66
# Normal           65
# Normal Weight     8
# Obese             4
# Name: BMI Category, dtype: int64

# %%
sns.barplot(data = sleep, x = "BMI Category",y = "Physical Activity Level")
# Out:
# <Axes: xlabel='BMI Category', ylabel='Physical Activity Level'>

# %%
sleep[sleep['Physical Activity Level']>60]['Heart Rate'].value_counts()
# Out:
# 70    63
# 68    36
# 75    32
# 72     3
# 67     2
# 83     2
# 86     2
# 65     2
# 69     1
# Name: Heart Rate, dtype: int64

# %%
sns.barplot(data = sleep ,x = 'Physical Activity Level', y = 'Heart Rate',hue = 'Gender')
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='Heart Rate'>

# %%
sleep[sleep['Physical Activity Level']>60]["Blood Pressure"].value_counts()
# Out:
# 140/95    65
# 120/80    34
# 130/85    33
# 115/78     2
# 142/92     2
# 139/91     2
# 118/75     2
# 117/76     1
# 121/79     1
# 122/80     1
# Name: Blood Pressure, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.barplot(data = sleep,x = 'Blood Pressure',y = 'Physical Activity Level',hue = 'Gender')
plt.tight_layout()

# %%
sleep['Age'].max()
# Out:
# 59

# %%
sleep['Age'].min()
# Out:
# 27

# %%
plt.figure(figsize = (14,8))
sns.countplot(data = sleep, x = 'Age',hue = "Gender")
plt.tight_layout()

# %%
sleep[sleep['Age']>27]['Occupation'].value_counts()
# Out:
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Scientist                4
# Software Engineer        3
# Sales Representative     2
# Manager                  1
# Name: Occupation, dtype: int64

# %%
plt.figure(figsize = (14,8))
sns.countplot(data = sleep, x = 'Occupation',hue = 'Gender')
plt.tight_layout()

# %%
plt.figure(figsize = (14,8))
sns.barplot(data = sleep, x = 'Age',y = 'Physical Activity Level')
plt.tight_layout()

# %%
plt.figure(figsize = (12,8))
sns.countplot(data = sleep, x = 'Age', hue = 'Sleep Disorder')
plt.tight_layout()

# %%
plt.figure(figsize = (12,8))
sns.countplot(data = sleep, x = 'Gender', hue = 'Sleep Disorder',palette = 'viridis')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize = (12,8))
sns.countplot(data = sleep , x = 'BMI Category', hue  = 'Sleep Disorder')
# Out:
# <Axes: xlabel='BMI Category', ylabel='count'>

# %%
plt.figure(figsize = (14,8))
sns.countplot(data = sleep, x = 'Occupation', hue = 'Sleep Disorder')
plt.tight_layout()

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = sleep, x = 'Sleep Disorder', y = 'Physical Activity Level',palette = 'viridis')
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='Physical Activity Level'>

# %%
plt.figure(figsize =(12,8))
sns.boxplot(data = sleep , x = 'Sleep Disorder', y = 'Stress Level')
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='Stress Level'>

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = sleep , x = 'Sleep Disorder', y = 'Sleep Duration')
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='Sleep Duration'>

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = sleep , x = 'Sleep Disorder', y = 'Quality of Sleep')
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='Quality of Sleep'>

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = sleep , x = 'Sleep Disorder', y = 'Heart Rate')
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='Heart Rate'>

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = sleep , x = 'Sleep Disorder', y = 'Daily Steps')
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='Daily Steps'>

# %%
plt.figure(figsize = (12,8))
sns.violinplot(data = sleep , x = 'Sleep Disorder', y = 'Age')
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='Age'>

# %%
#one hot encoding

# %%
sleep.drop(['Person ID'], axis = 1, inplace = True)

# %%
hot = pd.get_dummies(sleep[['Gender','Occupation','BMI Category','Blood Pressure']])
sleep = pd.concat([sleep, hot],axis = 1)

# %%
sleep.drop(['Gender','Occupation','BMI Category','Blood Pressure'], axis = 1, inplace = True)

# %%
sleep.head()
# Out:
#    Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0   27             6.1                 6                       42
# 1   28             6.2                 6                       60
# 2   28             6.2                 6                       60
# 3   28             5.9                 4                       30
# 4   28             5.9                 4                       30
#
#    Stress Level  Heart Rate  Daily Steps Sleep Disorder  Gender_Female  \
# 0             6          77         4200           None              0
# 1             8          75        10000           None              0
# 2             8          75        10000           None              0
# 3             8          85         3000    Sleep Apnea              0
# 4             8          85         3000    Sleep Apnea              0
#
#    Gender_Male  ...  Blood Pressure_130/85  Blood Pressure_130/86  \
# 0            1  ...                      0                      0
# ...

# %%
#rearanging columns

# %%
sleep = sleep[['Age', 'Sleep Duration', 'Quality of Sleep', 'Physical Activity Level',
       'Stress Level', 'Heart Rate', 'Daily Steps',
       'Gender_Female', 'Gender_Male', 'Occupation_Accountant',
       'Occupation_Doctor', 'Occupation_Engineer', 'Occupation_Lawyer',
       'Occupation_Manager', 'Occupation_Nurse',
       'Occupation_Sales Representative', 'Occupation_Salesperson',
       'Occupation_Scientist', 'Occupation_Software Engineer',
       'Occupation_Teacher', 'BMI Category_Normal',
       'BMI Category_Normal Weight', 'BMI Category_Obese',
       'BMI Category_Overweight', 'Blood Pressure_115/75',
       'Blood Pressure_115/78', 'Blood Pressure_117/76',
       'Blood Pressure_118/75', 'Blood Pressure_118/76',
       'Blood Pressure_119/77', 'Blood Pressure_120/80',
       'Blood Pressure_121/79', 'Blood Pressure_122/80',
       'Blood Pressure_125/80', 'Blood Pressure_125/82',
       'Blood Pressure_126/83', 'Blood Pressure_128/84',
       'Blood Pressure_128/85', 'Blood Pressure_129/84',
       'Blood Pressure_130/85', 'Blood Pressure_130/86',
       'Blood Pressure_131/86', 'Blood Pressure_132/87',
       'Blood Pressure_135/88', 'Blood Pressure_135/90',
       'Blood Pressure_139/91', 'Blood Pressure_140/90',
       'Blood Pressure_140/95','Sleep Disorder']]

# %%
sleep.head()
# Out:
#    Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0   27             6.1                 6                       42
# 1   28             6.2                 6                       60
# 2   28             6.2                 6                       60
# 3   28             5.9                 4                       30
# 4   28             5.9                 4                       30
#
#    Stress Level  Heart Rate  Daily Steps  Gender_Female  Gender_Male  \
# 0             6          77         4200              0            1
# 1             8          75        10000              0            1
# 2             8          75        10000              0            1
# 3             8          85         3000              0            1
# 4             8          85         3000              0            1
#
#    Occupation_Accountant  ...  Blood Pressure_130/85  Blood Pressure_130/86  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled = StandardScaler()

# %%
scaled.fit(sleep.drop('Sleep Disorder',axis = 1))
# Out:
# StandardScaler()

# %%
scaled_feat = scaled.transform(sleep.drop('Sleep Disorder',axis = 1))

# %%
sleep_feat = pd.DataFrame(scaled_feat,columns = sleep.columns[:-1] )

# %%
sleep_feat.columns
# Out:
# Index(['Age', 'Sleep Duration', 'Quality of Sleep', 'Physical Activity Level',
#        'Stress Level', 'Heart Rate', 'Daily Steps', 'Gender_Female',
#        'Gender_Male', 'Occupation_Accountant', 'Occupation_Doctor',
#        'Occupation_Engineer', 'Occupation_Lawyer', 'Occupation_Manager',
#        'Occupation_Nurse', 'Occupation_Sales Representative',
#        'Occupation_Salesperson', 'Occupation_Scientist',
#        'Occupation_Software Engineer', 'Occupation_Teacher',
#        'BMI Category_Normal', 'BMI Category_Normal Weight',
#        'BMI Category_Obese', 'BMI Category_Overweight',
#        'Blood Pressure_115/75', 'Blood Pressure_115/78',
#        'Blood Pressure_117/76', 'Blood Pressure_118/75',
#        'Blood Pressure_118/76', 'Blood Pressure_119/77',
#        'Blood Pressure_120/80', 'Blood Pressure_121/79',
#        'Blood Pressure_122/80', 'Blood Pressure_125/80',
#        'Blood Pressure_125/82', 'Blood Pressure_126/83',
# ...

# %%
sleep_feat.head()
# Out:
#         Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0 -1.753096       -1.298887         -1.098280                -0.825418
# 1 -1.637643       -1.173036         -1.098280                 0.039844
# 2 -1.637643       -1.173036         -1.098280                 0.039844
# 3 -1.637643       -1.550588         -2.771424                -1.402260
# 4 -1.637643       -1.550588         -2.771424                -1.402260
#
#    Stress Level  Heart Rate  Daily Steps  Gender_Female  Gender_Male  \
# 0      0.347021    1.654719    -1.619584      -0.989361     0.989361
# 1      1.475592    1.170474     1.970077      -0.989361     0.989361
# 2      1.475592    1.170474     1.970077      -0.989361     0.989361
# 3      1.475592    3.591698    -2.362273      -0.989361     0.989361
# 4      1.475592    3.591698    -2.362273      -0.989361     0.989361
#
#    Occupation_Accountant  ...  Blood Pressure_129/84  Blood Pressure_130/85  \
# ...

# %%
sleep.columns
# Out:
# Index(['Age', 'Sleep Duration', 'Quality of Sleep', 'Physical Activity Level',
#        'Stress Level', 'Heart Rate', 'Daily Steps', 'Gender_Female',
#        'Gender_Male', 'Occupation_Accountant', 'Occupation_Doctor',
#        'Occupation_Engineer', 'Occupation_Lawyer', 'Occupation_Manager',
#        'Occupation_Nurse', 'Occupation_Sales Representative',
#        'Occupation_Salesperson', 'Occupation_Scientist',
#        'Occupation_Software Engineer', 'Occupation_Teacher',
#        'BMI Category_Normal', 'BMI Category_Normal Weight',
#        'BMI Category_Obese', 'BMI Category_Overweight',
#        'Blood Pressure_115/75', 'Blood Pressure_115/78',
#        'Blood Pressure_117/76', 'Blood Pressure_118/75',
#        'Blood Pressure_118/76', 'Blood Pressure_119/77',
#        'Blood Pressure_120/80', 'Blood Pressure_121/79',
#        'Blood Pressure_122/80', 'Blood Pressure_125/80',
#        'Blood Pressure_125/82', 'Blood Pressure_126/83',
# ...

# %%
X = sleep_feat
y = sleep['Sleep Disorder']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logic = LogisticRegression()

# %%
logic.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
pred = logic.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
print(classification_report(y_test,pred))
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(accuracy_score(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#     Insomnia       0.94      0.77      0.85        22
#         None       0.90      0.95      0.92        64
#  Sleep Apnea       0.85      0.85      0.85        27
#
#     accuracy                           0.89       113
#    macro avg       0.90      0.86      0.88       113
# weighted avg       0.90      0.89      0.89       113
#
#
#
# [[17  3  2]
#  [ 1 61  2]
#  [ 0  4 23]]
#
#
# 0.8938053097345132

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
con = confusion_matrix(y_test,pred, labels = logic.classes_)

# %%
logic.classes_
# Out:
# array(['Insomnia', 'None', 'Sleep Apnea'], dtype=object)

# %%
consD = ConfusionMatrixDisplay(confusion_matrix=con,display_labels=['Insomnia', 'None', 'Sleep Apnea'])

# %%
consD.plot(cmap = 'RdGy')

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
trees = DecisionTreeClassifier()

# %%
trees.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predi = trees.predict(X_test)

# %%
print(classification_report(y_test,predi))
print('\n')
print(confusion_matrix(y_test,predi))
print('\n')
print(accuracy_score(y_test,predi))
# Out:
#               precision    recall  f1-score   support
#
#     Insomnia       0.89      0.77      0.83        22
#         None       0.92      0.94      0.93        64
#  Sleep Apnea       0.83      0.89      0.86        27
#
#     accuracy                           0.89       113
#    macro avg       0.88      0.87      0.87       113
# weighted avg       0.89      0.89      0.89       113
#
#
#
# [[17  2  3]
#  [ 2 60  2]
#  [ 0  3 24]]
#
#
# 0.8938053097345132

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
predic = rfc.predict(X_test)

# %%
print(classification_report(y_test,predic))
print('\n')
print(confusion_matrix(y_test,predic))
print('\n')
print(accuracy_score(y_test,predic))
# Out:
#               precision    recall  f1-score   support
#
#     Insomnia       0.94      0.77      0.85        22
#         None       0.92      0.95      0.94        64
#  Sleep Apnea       0.83      0.89      0.86        27
#
#     accuracy                           0.90       113
#    macro avg       0.90      0.87      0.88       113
# weighted avg       0.91      0.90      0.90       113
#
#
#
# [[17  2  3]
#  [ 1 61  2]
#  [ 0  3 24]]
#
#
# 0.9026548672566371

# %%
from sklearn.svm import SVC

# %%
svmc = SVC()

# %%
svmc.fit(X_train,y_train)
# Out:
# SVC()

# %%
predictions = svmc.predict(X_test)

# %%
print(classification_report(y_test,predictions))
print('\n')
print(confusion_matrix(y_test,predictions))
print('\n')
print(accuracy_score(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#     Insomnia       0.94      0.77      0.85        22
#         None       0.90      0.95      0.92        64
#  Sleep Apnea       0.85      0.85      0.85        27
#
#     accuracy                           0.89       113
#    macro avg       0.90      0.86      0.88       113
# weighted avg       0.90      0.89      0.89       113
#
#
#
# [[17  3  2]
#  [ 1 61  2]
#  [ 0  4 23]]
#
#
# 0.8938053097345132

# %%
param_grid= {'C':[1,10,100,1000], 'gamma':[1,0.1,0.01,0.001], 'kernel':['rbf']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.943 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.923 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.865 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.943 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.923 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.865 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.962 total time=   0.0s
# ...

# %%
pre = grid.predict(X_test)

# %%
print(classification_report(y_test,pre))
print('\n')
print(confusion_matrix(y_test,pre))
print('\n')
print(accuracy_score(y_test,pre))
# Out:
#               precision    recall  f1-score   support
#
#     Insomnia       0.90      0.82      0.86        22
#         None       0.92      0.95      0.94        64
#  Sleep Apnea       0.85      0.85      0.85        27
#
#     accuracy                           0.90       113
#    macro avg       0.89      0.87      0.88       113
# weighted avg       0.90      0.90      0.90       113
#
#
#
# [[18  2  2]
#  [ 1 61  2]
#  [ 1  3 23]]
#
#
# 0.9026548672566371
